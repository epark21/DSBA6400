# %% [markdown]
# <a href="https://colab.research.google.com/github/epark21/DSBA6400/blob/master/ar_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
df6=pd.read_csv('gdrive/My Drive/Colab Notebooks/df6.csv')

# %%
df6
# Out:
#        tic       date        skc  ...  type  positiveincrease  deathincrease
# 0        A   1/2/2020  61.840046  ...   NaN               NaN            NaN
# 1        A   1/3/2020  61.840046  ...   NaN               NaN            NaN
# 2        A   1/4/2020  61.840046  ...   NaN               NaN            NaN
# 3        A   1/5/2020  61.840046  ...   NaN               NaN            NaN
# 4        A   1/6/2020  61.840046  ...   NaN               NaN            NaN
# ...    ...        ...        ...  ...   ...               ...            ...
# 86698  ZTS  6/26/2020  72.861470  ...   NaN           44421.0          636.0
# 86699  ZTS  6/27/2020  72.861470  ...   NaN           43507.0          509.0
# 86700  ZTS  6/28/2020  72.861470  ...   NaN           42183.0          271.0
# 86701  ZTS  6/29/2020  72.861470  ...   NaN           36423.0          330.0
# 86702  ZTS  6/30/2020  72.861470  ...   NaN           44349.0          596.0
#
# [86703 rows x 19 columns]

# %%
df6['pskc'] = df6.groupby(['tic'])['skc'].shift(1)
df6['pske'] = df6.groupby(['tic'])['ske'].shift(1)
df6['pskv'] = df6.groupby(['tic'])['skv'].shift(1)
df6['pskm'] = df6.groupby(['tic'])['skm'].shift(1)
df6['psko'] = df6.groupby(['tic'])['sko'].shift(1)

# %%
df6.head(185)
# Out:
#      tic       date        skc  ...       pskv       pskm       psko
# 0      A   1/2/2020  61.840046  ...        NaN        NaN        NaN
# 1      A   1/3/2020  61.840046  ...  57.154064  64.289500  48.861420
# 2      A   1/4/2020  61.840046  ...  57.154064  64.289500  48.861420
# 3      A   1/5/2020  61.840046  ...  57.154064  64.289500  48.861420
# 4      A   1/6/2020  61.840046  ...  57.154064  64.289500  48.861420
# ..   ...        ...        ...  ...        ...        ...        ...
# 180    A  6/30/2020  41.802420  ...  64.372780  64.289500  56.353893
# 181  AAL   1/2/2020  43.756218  ...        NaN        NaN        NaN
# 182  AAL   1/3/2020  43.756218  ...  42.829273  42.019352  40.245766
# 183  AAL   1/4/2020  43.756218  ...  42.829273  42.019352  40.157078
# 184  AAL   1/5/2020  43.756218  ...  42.829273  42.019352  40.157078
#
# [185 rows x 24 columns]

# %%
skcc = (df6["skc"] - df6["pskc"])
df6["skcc"] = skcc
skec = (df6["ske"] - df6["pske"])
df6["skec"] = skec
skvc = (df6["skv"] - df6["pskv"])
df6["skvc"] = skvc
skmc = (df6["skm"] - df6["pskm"])
df6["skmc"] = skmc
skoc = (df6["sko"] - df6["psko"])
df6["skoc"] = skoc

# %%
df6.head(365)
# Out:
#      tic       date        skc        ske  ...      skec  skvc  skmc      skoc
# 0      A   1/2/2020  61.840046  82.027855  ...       NaN   NaN   NaN       NaN
# 1      A   1/3/2020  61.840046  82.027855  ...  0.000000   0.0   0.0  0.000000
# 2      A   1/4/2020  61.840046  82.027855  ...  0.000000   0.0   0.0  0.000000
# 3      A   1/5/2020  61.840046  82.027855  ...  0.000000   0.0   0.0  0.000000
# 4      A   1/6/2020  61.840046  82.027855  ...  0.000000   0.0   0.0  0.000000
# ..   ...        ...        ...        ...  ...       ...   ...   ...       ...
# 360  AAL  6/29/2020  46.028946  48.236626  ...  0.401486   0.0   0.0  0.455162
# 361  AAL  6/30/2020  45.115430  48.880170  ...  0.643544   0.0   0.0 -0.619612
# 362  AAP   1/2/2020  47.477314  50.492855  ...       NaN   NaN   NaN       NaN
# 363  AAP   1/3/2020  47.477314  50.492855  ...  0.000000   0.0   0.0  0.000000
# 364  AAP   1/4/2020  47.477314  50.492855  ...  0.000000   0.0   0.0  0.000000
#
# [365 rows x 29 columns]

# %%
df6.to_csv('newnew.csv')

# %%
newdfdf=pd.read_csv('gdrive/My Drive/Colab Notebooks/newdfdf.csv')
letters2=pd.read_csv('gdrive/My Drive/Colab Notebooks/letters2.csv', engine='python')

# %%
letters2
# Out:
#       tic  ... Media(e.g., company website, company social media, top leadership personal social media, etc.)
# 0     MMM  ...                                    company website
# 1     AOS  ...                                    company website
# 2     ABT  ...                      company website press release
# 3    ABBV  ...                                    company website
# 4    ABMD  ...                                    company website
# ..    ...  ...                                                ...
# 500   YUM  ...                                   businesswire.com
# 501  ZBRA  ...                                    company website
# 502   ZBH  ...                               company website news
# 503  ZION  ...                                    company website
# 504   ZTS  ...                                    company website
#
# [505 rows x 14 columns]

# %%
letters2['customer'].fillna(0, inplace=True)
letters2['employee'].fillna(0, inplace=True)
letters2['community'].fillna(0, inplace=True)
letters2['environment'].fillna(0, inplace=True)
letters2['general'].fillna(0, inplace=True)

# %%
letters2
# Out:
#       tic  ... Media(e.g., company website, company social media, top leadership personal social media, etc.)
# 0     MMM  ...                                    company website
# 1     AOS  ...                                    company website
# 2     ABT  ...                      company website press release
# 3    ABBV  ...                                    company website
# 4    ABMD  ...                                    company website
# ..    ...  ...                                                ...
# 500   YUM  ...                                   businesswire.com
# 501  ZBRA  ...                                    company website
# 502   ZBH  ...                               company website news
# 503  ZION  ...                                    company website
# 504   ZTS  ...                                    company website
#
# [505 rows x 14 columns]

# %%
letterdf=pd.merge(newdfdf, letters2, on=['tic','date'],how='left')

# %%
letterdf
# Out:
#        tic  ... Media(e.g., company website, company social media, top leadership personal social media, etc.)_y
# 0        A  ...                                                NaN
# 1        A  ...                                                NaN
# 2        A  ...                                                NaN
# 3        A  ...                                                NaN
# 4        A  ...                                                NaN
# ...    ...  ...                                                ...
# 86698  ZTS  ...                                                NaN
# 86699  ZTS  ...                                                NaN
# 86700  ZTS  ...                                                NaN
# 86701  ZTS  ...                                                NaN
# 86702  ZTS  ...                                                NaN
#
# [86703 rows x 36 columns]

# %%
final=pd.read_csv('gdrive/My Drive/Colab Notebooks/final.csv', parse_dates=['date'])

# %%
final = final.replace([np.inf, -np.inf], np.nan)

# %%
final['positiveincrease'] = final['positiveincrease'].fillna(0)
final['deathincrease'] = final['deathincrease'].fillna(0)

# %%
final
# Out:
#        Unnamed: 0  tic       date  ...  environment  general  Media
# 0               0    A 2020-01-02  ...          NaN      NaN    NaN
# 1               1    A 2020-01-03  ...          NaN      NaN    NaN
# 2               2    A 2020-01-04  ...          NaN      NaN    NaN
# 3               3    A 2020-01-05  ...          NaN      NaN    NaN
# 4               4    A 2020-01-06  ...          NaN      NaN    NaN
# ...           ...  ...        ...  ...          ...      ...    ...
# 86698       86698  ZTS 2020-06-26  ...          NaN      NaN    NaN
# 86699       86699  ZTS 2020-06-27  ...          NaN      NaN    NaN
# 86700       86700  ZTS 2020-06-28  ...          NaN      NaN    NaN
# 86701       86701  ZTS 2020-06-29  ...          NaN      NaN    NaN
# 86702       86702  ZTS 2020-06-30  ...          NaN      NaN    NaN
#
# [86703 rows x 32 columns]

# %%
final = final.drop(columns=['Unnamed: 0'])

# %%
final
# Out:
#        tic       date        skc  skcc  ...  community  environment  general  Media
# 0        A 2020-01-02  61.840046   NaN  ...        NaN          NaN      NaN    NaN
# 1        A 2020-01-03  61.840046   0.0  ...        NaN          NaN      NaN    NaN
# 2        A 2020-01-04  61.840046   0.0  ...        NaN          NaN      NaN    NaN
# 3        A 2020-01-05  61.840046   0.0  ...        NaN          NaN      NaN    NaN
# 4        A 2020-01-06  61.840046   0.0  ...        NaN          NaN      NaN    NaN
# ...    ...        ...        ...   ...  ...        ...          ...      ...    ...
# 86698  ZTS 2020-06-26  72.861470   0.0  ...        NaN          NaN      NaN    NaN
# 86699  ZTS 2020-06-27  72.861470   0.0  ...        NaN          NaN      NaN    NaN
# 86700  ZTS 2020-06-28  72.861470   0.0  ...        NaN          NaN      NaN    NaN
# 86701  ZTS 2020-06-29  72.861470   0.0  ...        NaN          NaN      NaN    NaN
# ...

# %%
df1 = final[['date','positiveincrease']]
df1.head(3)
df2 = final[['date','deathincrease']]
df3 = final[['date','ar']]
df4 = final[['date','skc']]
df5 = final[['date','ske']]
df6 = final[['date','skv']]
df7 = final[['date','skm']]
df8 = final[['date','sko']]

# %%
# Setting the Date as Index
df_ts = df1.set_index('date')
df_ts.sort_index(inplace=True)
print (type(df_ts))
print (df_ts.head(3))
print ("========================")
print (df_ts.tail(3))

# Setting the Date as Index
df_ts1 = df2.set_index('date')
df_ts1.sort_index(inplace=True)

df_ts3 = df3.set_index('date')
df_ts3.sort_index(inplace=True)

df_ts4 = df4.set_index('date')
df_ts4.sort_index(inplace=True)

df_ts5 = df5.set_index('date')
df_ts5.sort_index(inplace=True)

df_ts6 = df6.set_index('date')
df_ts6.sort_index(inplace=True)

df_ts7 = df7.set_index('date')
df_ts7.sort_index(inplace=True)

df_ts8 = df8.set_index('date')
df_ts8.sort_index(inplace=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#             positiveincrease
# date
# 2020-01-02               0.0
# 2020-01-02               0.0
# 2020-01-02               0.0
# ...
#             positiveincrease
# date
# 2020-06-30           44349.0
# 2020-06-30           44349.0
# 2020-06-30           44349.0

# %%
df_ts1
# Out:
#             deathincrease
# date
# 2020-01-02            0.0
# 2020-01-02            0.0
# 2020-01-02            0.0
# 2020-01-02            0.0
# 2020-01-02            0.0
# ...                   ...
# 2020-06-30          596.0
# 2020-06-30          596.0
# 2020-06-30          596.0
# 2020-06-30          596.0
# 2020-06-30          596.0
#
# [86703 rows x 1 columns]

# %%
df_ts.plot()
df_ts1.plot()
df_ts3.plot()
df_ts4.plot()
df_ts5.plot()
df_ts6.plot()
df_ts7.plot()
df_ts8.plot()

# %%
# Dickey Fuller Test Function
def test_stationarity(timeseries):
    # Perform Dickey-Fuller test:
    from statsmodels.tsa.stattools import adfuller
    print('Results of Dickey-Fuller Test:')
    print ("==============================================")
    
    dftest = adfuller(timeseries, autolag='AIC')
    
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic', 'p-value', '#lags Used', 'Number of Observations Used'])
    
    for key, value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    
    print(dfoutput)

# %%
ts = df_ts['positiveincrease']
test_stationarity(ts)

ts1 = df_ts1['deathincrease']
test_stationarity(ts)
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# Results of Dickey-Fuller Test:
# ...
# Test Statistic                    -0.347943
# p-value                            0.918434
# #lags Used                         0.000000
# Number of Observations Used    86702.000000
# Critical Value (1%)               -3.430425
# Critical Value (5%)               -2.861573
# Critical Value (10%)              -2.566788
# dtype: float64
# Results of Dickey-Fuller Test:
# ...
# Test Statistic                    -0.347943
# p-value                            0.918434
# #lags Used                         0.000000
# Number of Observations Used    86702.000000
# Critical Value (1%)               -3.430425
# Critical Value (5%)               -2.861573
# Critical Value (10%)              -2.566788
# dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt
